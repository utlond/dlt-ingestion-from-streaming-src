# %% [markdown]
# ##### Streaming source

# %%
# %sql
select * from nyctaxi_copy.trips_src;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##### Ingested dataset (from the continuous DLT pipeline)

# %%
# %sql
select * from nyctaxi_dlt.nyctaxidata_ingested_from_trips_src;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ##### Latest batch aggregations

# %%
# %sql
select * from nyctaxi_dlt.trips_agg_by_zip_codes_latest_batch;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select distinct zip_bin_lower_bound, zip_bin_upper_bound, trip_count, avg_duration_mins 
from nyctaxi_dlt.trips_agg_by_zip_codes_latest_batch;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>zip_bin_lower_bound</th><th>zip_bin_upper_bound</th><th>trip_count</th><th>avg_duration_mins</th></tr></thead><tbody><tr><td>10000.0</td><td>10100.0</td><td>31</td><td>55.0</td></tr><tr><td>11100.0</td><td>11200.0</td><td>1</td><td>12.0</td></tr><tr><td>10100.0</td><td>10200.0</td><td>4</td><td>5.0</td></tr></tbody></table></div>

# %% [markdown]
# ##### Historical aggregations

# %%
# %sql
select * from nyctaxi_dlt.trips_agg_by_zip_codes_historical;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select distinct zip_bin_lower_bound, zip_bin_upper_bound, trip_count, avg_duration_mins 
from nyctaxi_dlt.trips_agg_by_zip_codes_historical;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
